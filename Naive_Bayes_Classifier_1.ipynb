# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimi2607/Machine_Learning/blob/main/Naive_Bayes_Classifier_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin', 'Embarked', 'SibSp', 'Parch'], axis = 'columns', inplace =True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
target = df.Survived
inputs = df.drop('Survived', axis = 'columns')

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head()
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False
# 3    True  False
# 4   False   True

# %%
inputs = pd.concat([inputs, dummies], axis = 'columns')
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False
# 3       1  female  35.0  53.1000    True  False
# 4       3    male  35.0   8.0500   False   True

# %%
inputs.drop('Sex', axis = 'columns', inplace = True)
inputs.head()
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False
# 3       1  35.0  53.1000    True  False
# 4       3  35.0   8.0500   False   True

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     714 non-null    float64
#  2   Fare    891 non-null    float64
#  3   female  891 non-null    bool
#  4   male    891 non-null    bool
# dtypes: bool(2), float64(2), int64(1)
# memory usage: 22.8 KB

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head()
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False
# 3       1  35.0  53.1000    True  False
# 4       3  35.0   8.0500   False   True

# %%
inputs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     891 non-null    float64
#  2   Fare    891 non-null    float64
#  3   female  891 non-null    bool
#  4   male    891 non-null    bool
# dtypes: bool(2), float64(2), int64(1)
# memory usage: 22.8 KB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size = 0.2)

# %%
len(X_train)
# Out:
# 712

# %%
X_train
# Out:
#      Pclass        Age     Fare  female   male
# 160       3  44.000000  16.1000   False   True
# 748       1  19.000000  53.1000   False   True
# 530       2   2.000000  26.0000    True  False
# 330       3  29.699118  23.2500    True  False
# 414       3  44.000000   7.9250   False   True
# ..      ...        ...      ...     ...    ...
# 370       1  25.000000  55.4417   False   True
# 383       1  35.000000  52.0000    True  False
# 469       3   0.750000  19.2583    True  False
# 427       2  19.000000  26.0000    True  False
# 4         3  35.000000   8.0500   False   True
#
# [712 rows x 5 columns]

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.8044692737430168

# %%
X_test
# Out:
#      Pclass        Age     Fare  female   male
# 178       2  30.000000  13.0000   False   True
# 367       3  29.699118   7.2292    True  False
# 591       1  52.000000  78.2667    True  False
# 463       2  48.000000  13.0000   False   True
# 798       3  30.000000   7.2292   False   True
# ..      ...        ...      ...     ...    ...
# 881       3  33.000000   7.8958   False   True
# 833       3  23.000000   7.8542   False   True
# 549       2   8.000000  36.7500   False   True
# 459       3  29.699118   7.7500   False   True
# 612       3  29.699118  15.5000    True  False
#
# [179 rows x 5 columns]

# %%
y_test
# Out:
# 178    0
# 367    1
# 591    1
# 463    0
# 798    0
#       ..
# 881    0
# 833    0
# 549    1
# 459    0
# 612    1
# Name: Survived, Length: 179, dtype: int64

# %%
model.predict(X_test[:10])
# Out:
# array([0, 1, 1, 0, 0, 0, 0, 1, 1, 1])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.97838355, 0.02161645],
#        [0.11154478, 0.88845522],
#        [0.00211003, 0.99788997],
#        [0.97996662, 0.02003338],
#        [0.99037091, 0.00962909],
#        [0.86017662, 0.13982338],
#        [0.99110457, 0.00889543],
#        [0.04398274, 0.95601726],
#        [0.10680986, 0.89319014],
#        [0.00736354, 0.99263646]])
