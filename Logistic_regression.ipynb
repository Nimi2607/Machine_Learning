# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimi2607/Machine_Learning/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('insurance_data.csv')

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(df[['age']], df.bought_insurance)
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1, random_state = 20)

# %%
X_test
# Out:
#     age
# 13   29
# 4    46
# 1    25

# %%
X_train
# Out:
#     age
# 10   18
# 26   23
# 12   27
# 18   19
# 25   54
# 23   45
# 22   40
# 21   26
# 5    56
# 24   50
# 19   18
# 14   49
# 17   58
# 6    55
# 16   25
# 8    62
# 0    22
# 2    47
# 7    60
# 11   28
# 20   21
# 9    61
# 15   55
# 3    52

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')
plt.plot(X_test, model.predict(X_test), color='blue')

# %%
model.predict_proba(X_test)
# Out:
# array([[0.76521326, 0.23478674],
#        [0.28378442, 0.71621558],
#        [0.84254653, 0.15745347]])
